# %%
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv('AviationData.csv', encoding ='cp1252',low_memory=False)

df['Event.Date'] = pd.to_datetime(df['Event.Date'],format='%Y-%m-%d')

df['Year'] = df['Event.Date'].dt.year

# %%
cols_to_drop = ['Air.carrier', 'Purpose.of.flight', 'Latitude' , 'Longitude', 'Publication.Date', 'Accident.Number', 'Event.Id', 'Airport.Code' , 'Airport.Name' , 'Registration.Number' , 'FAR.Description']

# %%
df_clean_cols = df.drop(cols_to_drop, axis=1)
df_clean_cols.head()
# good_makes = ['Boeing', 'Airbus Industrie', 'Airbus', 'Bombardier' , 'Boeing Stearman' , 'Gulfstream Aerospace' , 'Boeing Helicopters Div.' , 'Gulfstream American' , 'Gulfstream-schweizer' , 'Bombardier Inc.' , 'Bombardier Aerospace Inc.' , 'Airbus Industries' , 'Gulfstream']

df_clean_rows = df_clean_cols[(df_clean_cols['Amateur.Built'] != True)]
df_clean_rows.isna().sum()

total_passengers = df_clean_rows['Total.Fatal.Injuries'] + df_clean_rows['Total.Serious.Injuries'] + df_clean_rows['Total.Minor.Injuries'] + df_clean_rows['Total.Uninjured']



df_clean_rows['Total_passengers'] = total_passengers
Safe_pass = (df_clean_rows['Total.Minor.Injuries'] + df_clean_rows['Total.Uninjured']) / (df_clean_rows['Total_passengers']) * 100
Injured_pass = (df_clean_rows['Total.Serious.Injuries'] / df_clean_rows['Total_passengers']) * 100
dead_pass = (df_clean_rows['Total.Fatal.Injuries'] / df_clean_rows['Total_passengers']) * 100

df_clean_rows['Fatality_Pecentage'] = dead_pass
df_clean_rows['Serious_Inj_Percentage'] = Injured_pass
df_clean_rows['Minor/NonInj_Percentage'] = Safe_pass

df_clean_rows.isna().sum()

df_clean_pass_nas = df_clean_rows.dropna(subset= ['Total_passengers'])

df_clean_pass_zeros = df_clean_pass_nas.drop(df_clean_pass_nas[df_clean_pass_nas['Total_passengers'] == 0].index, axis = 0)



df_clean_pass_zeros
# Out:
#       Investigation.Type Event.Date         Location        Country  \
# 0               Accident 1948-10-24  MOOSE CREEK, ID  United States
# 1               Accident 1962-07-19   BRIDGEPORT, CA  United States
# 3               Accident 1977-06-19       EUREKA, CA  United States
# 6               Accident 1981-08-01       COTTON, MN  United States
# 7               Accident 1982-01-01      PULLMAN, WA  United States
# ...                  ...        ...              ...            ...
# 88882           Accident 2022-12-21      Reserve, LA  United States
# 88883           Accident 2022-12-22      Brasnorte,          Brazil
# 88884           Accident 2022-12-26    Annapolis, MD  United States
# 88886           Accident 2022-12-26       Payson, AZ  United States
# 88888           Accident 2022-12-29       Athens, GA  United States
#
#       Injury.Severity Aircraft.damage Aircraft.Category  \
# 0            Fatal(2)       Destroyed               NaN
# 1            Fatal(4)       Destroyed               NaN
# 3            Fatal(2)       Destroyed               NaN
# 6            Fatal(4)       Destroyed               NaN
# 7           Non-Fatal     Substantial          Airplane
# ...               ...             ...               ...
# 88882           Minor             NaN               NaN
# 88883           Fatal             NaN               NaN
# 88884           Minor             NaN               NaN
# 88886       Non-Fatal     Substantial          Airplane
# 88888           Minor             NaN               NaN
#
#                               Make      Model Amateur.Built  ...  \
# 0                          Stinson      108-3            No  ...
# 1                            Piper   PA24-180            No  ...
# 3                         Rockwell        112            No  ...
# 6                           Cessna        180            No  ...
# 7                           Cessna        140            No  ...
# ...                            ...        ...           ...  ...
# 88882  GRUMMAN AMERICAN AVN. CORP.      AA-5B            No  ...
# 88883                  AIR TRACTOR      AT502            No  ...
# 88884                        PIPER  PA-28-151            No  ...
# 88886   AMERICAN CHAMPION AIRCRAFT      8GCBC            No  ...
# 88888                        PIPER  PA-24-260            No  ...
#
#        Total.Minor.Injuries Total.Uninjured Weather.Condition  \
# 0                       0.0             0.0               UNK
# 1                       0.0             0.0               UNK
# 3                       0.0             0.0               IMC
# 6                       0.0             0.0               IMC
# 7                       0.0             2.0               VMC
# ...                     ...             ...               ...
# 88882                   0.0             1.0               NaN
# 88883                   0.0             0.0               NaN
# 88884                   0.0             0.0               NaN
# 88886                   0.0             1.0               VMC
# 88888                   0.0             1.0               NaN
#
#        Broad.phase.of.flight   Report.Status  Year  Total_passengers  \
# 0                     Cruise  Probable Cause  1948               2.0
# 1                    Unknown  Probable Cause  1962               4.0
# 3                     Cruise  Probable Cause  1977               2.0
# 6                    Unknown  Probable Cause  1981               4.0
# 7                    Takeoff  Probable Cause  1982               2.0
# ...                      ...             ...   ...               ...
# 88882                    NaN             NaN  2022               2.0
# 88883                    NaN             NaN  2022               1.0
# 88884                    NaN             NaN  2022               1.0
# 88886                    NaN             NaN  2022               1.0
# 88888                    NaN             NaN  2022               2.0
#
#       Fatality_Pecentage Serious_Inj_Percentage Minor/NonInj_Percentage
# 0                  100.0                    0.0                     0.0
# 1                  100.0                    0.0                     0.0
# 3                  100.0                    0.0                     0.0
# 6                  100.0                    0.0                     0.0
# 7                    0.0                    0.0                   100.0
# ...                  ...                    ...                     ...
# 88882                0.0                   50.0                    50.0
# 88883              100.0                    0.0                     0.0
# 88884                0.0                  100.0                     0.0
# 88886                0.0                    0.0                   100.0
# 88888                0.0                   50.0                    50.0
#
# [73276 rows x 25 columns]

# %%
df_clean_pass_zeros.to_csv('AviationDataCleaned.csv')
