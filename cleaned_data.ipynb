# %%
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv(r'C:\Users\bpolk\Documents\Flatiron\Materials\Phase_1\Project1\AviationData.csv', encoding ='cp1252')
df.info()
# Out:
# C:\Users\bpolk\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (6,7,28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88889 entries, 0 to 88888
# Data columns (total 31 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Id                88889 non-null  object
#  1   Investigation.Type      88889 non-null  object
#  2   Accident.Number         88889 non-null  object
#  3   Event.Date              88889 non-null  object
#  4   Location                88837 non-null  object
#  5   Country                 88663 non-null  object
#  6   Latitude                34382 non-null  object
#  7   Longitude               34373 non-null  object
#  8   Airport.Code            50249 non-null  object
#  9   Airport.Name            52790 non-null  object
#  10  Injury.Severity         87889 non-null  object
#  11  Aircraft.damage         85695 non-null  object
#  12  Aircraft.Category       32287 non-null  object
#  13  Registration.Number     87572 non-null  object
#  14  Make                    88826 non-null  object
#  15  Model                   88797 non-null  object
#  16  Amateur.Built           88787 non-null  object
#  17  Number.of.Engines       82805 non-null  float64
#  18  Engine.Type             81812 non-null  object
#  19  FAR.Description         32023 non-null  object
#  20  Schedule                12582 non-null  object
#  21  Purpose.of.flight       82697 non-null  object
#  22  Air.carrier             16648 non-null  object
#  23  Total.Fatal.Injuries    77488 non-null  float64
#  24  Total.Serious.Injuries  76379 non-null  float64
#  25  Total.Minor.Injuries    76956 non-null  float64
#  26  Total.Uninjured         82977 non-null  float64
#  27  Weather.Condition       84397 non-null  object
#  28  Broad.phase.of.flight   61724 non-null  object
#  29  Report.Status           82508 non-null  object
#  30  Publication.Date        75118 non-null  object
# dtypes: float64(5), object(26)
# memory usage: 21.0+ MB

# %%
cols_to_drop = ['Air.Carrier', 'Purpose.of.flight', 'Latitude' , 'Longitude', 'Publication.Date', 'Accident.Number', 'Event.Id', 'Airport.Code' , 'Airport.Name' , 'Registration.Number' , 'FAR.Description']

# %%
df_clean_cols = df.drop(cols_to_drop, axis=1)
df_clean_cols.head()
good_makes = ['Boeing', 'Airbus Industrie', 'Airbus', 'Bombardier' , 'Boeing Stearman' , 'Gulfstream Aerospace' , 'Boeing Helicopters Div.' , 'Gulfstream American' , 'Gulfstream-schweizer' , 'Bombardier Inc.' , 'Bombardier Aerospace Inc.' , 'Airbus Industries' , 'Gulfstream']

df_clean_rows = df_clean_cols[(df_clean_cols['Amateur.Built'] != True) & ((df_clean_cols['Aircraft.Category'] == 'Airplane') | (df_clean_cols.Make.isin(good_makes)))]
df_clean_rows.isna().sum()

total_passengers = df_clean_rows['Total.Fatal.Injuries'] + df_clean_rows['Total.Serious.Injuries'] + df_clean_rows['Total.Minor.Injuries'] + df_clean_rows['Total.Uninjured']



df_clean_rows['Total_passengers'] = total_passengers
Safe_pass = (df_clean_rows['Total.Minor.Injuries'] + df_clean_rows['Total.Uninjured']) / (df_clean_rows['Total_passengers']) * 100
Injured_pass = (df_clean_rows['Total.Serious.Injuries'] / df_clean_rows['Total_passengers']) * 100
dead_pass = (df_clean_rows['Total.Fatal.Injuries'] / df_clean_rows['Total_passengers']} * 100

df_clean_rows['Fatality_Pecentage'] = dead_pass
df_clean_rows['Serious_Inj_Percentage'] = Injured_pass
df_clean_rows['Minor/NonInj_Percentage'] = Safe_pass

df_clean_rows.isna().sum()

df_clean_pass_nas = df_clean_rows.dropna(subset= ['Total_passengers'])

df_clean_pass_zeros = df_clean_pass_nas.drop(df_clean_pass_nas[df_clean_pass_nas['Total_passengers'] == 0].index, axis = 0)



df_clean_pass_zeros
# Out:
# <ipython-input-62-d8fe97344ea8>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean_rows['Total_passengers'] = total_passengers
#       Investigation.Type        Country Injury.Severity Aircraft.damage  \
# 7               Accident  United States       Non-Fatal     Substantial
# 8               Accident  United States       Non-Fatal     Substantial
# 12              Accident  United States       Non-Fatal       Destroyed
# 13              Accident  United States        Fatal(1)       Destroyed
# 14              Accident  United States        Fatal(1)       Destroyed
# ...                  ...            ...             ...             ...
# 88869           Accident  United States       Non-Fatal     Substantial
# 88873           Accident  United States       Non-Fatal     Substantial
# 88876           Accident  United States       Non-Fatal     Substantial
# 88877           Accident  United States           Minor     Substantial
# 88886           Accident  United States       Non-Fatal     Substantial
#
#       Aircraft.Category                        Make    Model Amateur.Built  \
# 7              Airplane                      Cessna      140            No
# 8              Airplane                      Cessna     401B            No
# 12             Airplane                    Bellanca   17-30A            No
# 13             Airplane                      Cessna    R172K            No
# 14             Airplane                      Navion        A            No
# ...                 ...                         ...      ...           ...
# 88869          Airplane                       PIPER     PA42            No
# 88873          Airplane          CIRRUS DESIGN CORP     SR22            No
# 88876          Airplane                  SWEARINGEN  SA226TC            No
# 88877          Airplane                      CESSNA    R172K            No
# 88886          Airplane  AMERICAN CHAMPION AIRCRAFT    8GCBC            No
#
#        Number.of.Engines    Engine.Type Schedule  \
# 7                    1.0  Reciprocating      NaN
# 8                    2.0  Reciprocating      NaN
# 12                   1.0  Reciprocating      NaN
# 13                   1.0  Reciprocating      NaN
# 14                   1.0  Reciprocating      NaN
# ...                  ...            ...      ...
# 88869                2.0            NaN      NaN
# 88873                1.0            NaN      NaN
# 88876                2.0            NaN     SCHD
# 88877                1.0            NaN      NaN
# 88886                1.0            NaN      NaN
#
#                          Air.carrier  Total.Fatal.Injuries  \
# 7                                NaN                   0.0
# 8                                NaN                   0.0
# 12                               NaN                   0.0
# 13                               NaN                   1.0
# 14                               NaN                   1.0
# ...                              ...                   ...
# 88869                            NaN                   0.0
# 88873  SKY WEST AVIATION INC TRUSTEE                   0.0
# 88876                            NaN                   0.0
# 88877               GERBER RICHARD E                   0.0
# 88886                            NaN                   0.0
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured  \
# 7                         0.0                   0.0              2.0
# 8                         0.0                   0.0              2.0
# 12                        0.0                   1.0              0.0
# 13                        0.0                   0.0              0.0
# 14                        0.0                   0.0              0.0
# ...                       ...                   ...              ...
# 88869                     0.0                   0.0              1.0
# 88873                     0.0                   0.0              1.0
# 88876                     0.0                   0.0              1.0
# 88877                     1.0                   0.0              0.0
# 88886                     0.0                   0.0              1.0
#
#       Weather.Condition Broad.phase.of.flight   Report.Status  \
# 7                   VMC               Takeoff  Probable Cause
# 8                   IMC               Landing  Probable Cause
# 12                  IMC                Cruise  Probable Cause
# 13                  IMC               Takeoff  Probable Cause
# 14                  IMC                Cruise  Probable Cause
# ...                 ...                   ...             ...
# 88869               NaN                   NaN             NaN
# 88873               VMC                   NaN             NaN
# 88876               NaN                   NaN             NaN
# 88877               VMC                   NaN             NaN
# 88886               VMC                   NaN             NaN
#
#        Total_passengers
# 7                   2.0
# 8                   2.0
# 12                  1.0
# 13                  1.0
# 14                  1.0
# ...                 ...
# 88869               1.0
# 88873               1.0
# 88876               1.0
# 88877               1.0
# 88886               1.0
#
# [24403 rows x 20 columns]

# %%
list = list(df_clean_pass_zeros['Model'].unique())

df_clean_pass_zeros['Model'].value_counts()
# Out:
# 172               805
# 152               366
# 182               313
# PA28              267
# SR22              248
#                  ...
# M20L                1
# PA28-150            1
# HAWK SSC            1
# PT-13/E-75          1
# TIGER MOTH R80      1
# Name: Model, Length: 4927, dtype: int64
